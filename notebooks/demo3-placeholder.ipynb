# %% [markdown]
# # Demo 3 - Placeholder
#
# > **Status: coming soon.** This notebook is a structural placeholder that
# > follows the same template as `demo1-token-limits.ipynb` so it can be
# > filled in later without refactoring `shared/`.
#
# **Scenario:** TBD: describe the governance scenario for Demo 3 (e.g. per-team chargeback / cost attribution).

# %%
import sys
sys.path.append("..")

from shared import auth, config, apim, display

cfg = config.load_config(interactive=True)
config.validate_config(cfg)
display.header("Configuration loaded (see 00-setup-and-validation.ipynb for details)")

# %% [markdown]
# ## Scenario & talk track
#
# Explain the governance problem this demo illustrates and why it matters.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Scenario & talk track

# %% [markdown]
# ## Demo isolation
#
# Create a dedicated APIM subscription (and any other isolation mechanism, e.g. a unique run suffix) so this demo's counters/state never mix with other demos or real traffic.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Demo isolation

# %% [markdown]
# ## Configure (policy apply)
#
# Create/ensure the API, backend, named values, and apply the relevant policy at API scope -- before any calls are made.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Configure (policy apply)

# %% [markdown]
# ## Baseline
#
# Make a single baseline call and show the relevant response headers/behavior.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Baseline

# %% [markdown]
# ## Demonstrate
#
# Drive the specific governance behavior this demo is about (fill in for this demo).
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Demonstrate

# %% [markdown]
# ## Observe
#
# Show a consolidated results table and summarize what was observed.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Observe

# %% [markdown]
# ## Reset / Cleanup
#
# Reset the demo's isolation key (instant reset) and, optionally, clean up the created resources idempotently.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Reset / Cleanup

# %% [markdown]
# ## Talk track
#
# Recap for the workshop audience: what governance control was shown and why it matters.
#
# _TODO: implement for Demo 3._

# %%
# TODO: Demo 3 - Talk track
